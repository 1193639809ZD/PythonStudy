# %%
import torch

# %%
a = torch.randn(3, 3)
print(a)
# Out:
# tensor([[ 1.3136,  0.6370,  0.8846],
#         [ 1.0726, -0.8149, -0.9703],
#         [-0.1231,  1.5733,  1.7810]])

# %%
b = torch.randn(4, 4)
print(b)
# Out:
# tensor([[ 0.9762, -0.3125,  0.5370,  0.7030],
#         [ 1.5386, -0.6409, -0.1141, -0.6778],
#         [ 1.3231, -1.9415, -0.4731, -0.2417],
#         [-1.6351,  0.5128,  0.7201, -0.1221]])
