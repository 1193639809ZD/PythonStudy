# %%
import inspect

# %%
def eveleaf():
    callname = inspect.stack()
    return callname

# %%
callname = eveleaf()

# %%
print('[debug] enter: {}'.format(callname[1][4]))
# Out:
# [debug] enter: ['callname = eveleaf()\n']
